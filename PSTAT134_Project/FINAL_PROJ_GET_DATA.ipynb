# %%
import alpha_vantage
import pandas

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='QRUZFNK31H8I2RDT', output_format='pandas')
# Get pandas object with the intraday data and another with  the call's metadata
myList = ["QQQ", "TAGS", "CARZ"]
data_QQQ, meta_data_QQQ = ts.get_monthly(myList[0])
data_TAGS, meta_data_TAGS = ts.get_monthly(myList[1])
data_CARZ, meta_data_CARZ = ts.get_monthly(myList[2])

# %%
#print(data_QQQ)
#print(data_TAGS)
#print(data_CARZ)
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# date
# 2012-04-30  50.9900  51.0000  48.0000   48.8000     1770.0
# 2012-05-31  48.4000  48.4000  45.7100   46.7300     7341.0
# 2012-06-29  46.7300  53.0000  45.1100   48.0100    55571.0
# 2012-07-31  54.1220  73.1799  51.0000   55.5400    17101.0
# 2012-08-31  55.8000  55.8000  53.4800   54.8999     9984.0
# 2012-09-28  54.8999  54.9300  51.6500   52.3600    10325.0
# 2012-10-31  53.2000  53.2500  51.8033   51.8033    10086.0
# 2012-11-30  51.8033  51.8033  49.8966   50.7600     2700.0
# 2012-12-31  51.4100  51.4600  48.5900   48.5900     6975.0
# 2013-01-31  48.0200  48.8500  47.4400   48.8500     9565.0
# 2013-02-28  48.8500  48.9490  45.4200   45.5300     2350.0
# 2013-03-28  45.5300  46.0000  44.5000   44.5000     2505.0
# 2013-04-30  46.0000  46.0000  42.2300   43.8900    11999.0
# 2013-05-31  43.8900  44.4100  42.0000   42.1100     9899.0
# 2013-06-28  44.5500  44.9500  41.3500   41.3500    21880.0
# ...
